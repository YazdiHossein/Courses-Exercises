# %% [markdown]
# Hossein Yazdi. Python Assignment 1 Turtle Mania June - 2022     Shahiad-Tower-by-Turtle-in-Python

# %% [markdown]
# # Two-Turtles Game Time
# The Turtle is a library by which it is possible to play with using Python commands after the import into Juypter Notebooks.
# **Note** Turtle will open in a separate kernal window. You may have to look for it.
#
# The Turtle must be run straight off on Anaconda 3 or if not work, then it might use the extension that is installed by take benefit of the following commands in the Anaconda run cmd prompt.
# <br>
# <code>$ pip install ipyturtle <br>
# $ jupyter nbextension enable --py --sys-prefix ipyturtle</code>
#
# Turtle Docummentation is available at [Turtle Docs](https://docs.python.org/3.3/library/turtle.html?highlight=turtle).
#
# Create the shape classic as the first turtle and get it to draw a tower
# # Shahiad Tower
# The Azadi Tower, formerly known as the Shahyad Tower, is a monument located on square with the same name in Tehran, Iran.
# It is one of the landmarks of Tehran, marking the west entrance to the city, and is part of the Azadi Cultural Complex,
# which also includes an underground museum.
#
# The tower is about 45 metres (148 ft) tall and is completely clad in cut marble. It was commissioned by Mohammad Reza Pahlavi, the last Shah of Iran, to mark the 2,500-year celebration of the Persian Empire and completed in 1971.
#
# After winning a competition, architect Hossein Amanat was tasked to design the tower. His ideas were based upon classical and post-classical Iranian architecture, popular influences on art in the 1960s following the White Revolution.

# %%
# pip install ipyturtle

# %% [markdown]
# ## First Import the Turtle

# %%
import turtle # import the library
import time # import the library

# %% [markdown]
# By using variables we have more control over Turtle. By changing the variable values we can change its behaviour.

# %%
turtle.clearscreen() # Clear the screen at the first step that can be ignored firstly 
first_turtle = turtle.Turtle() # Create an instance of the first turtle
first_turtle.shape("classic") # Also, in this library there are other shapes possible, such as circle, square, arrow, turtle, triangle, classic) 
first_turtle.color("black") # Set a colour of black
first_turtle.width(3) # set a pen size 

# Using the commands of forward, left, right, and loops 

# Performing the right part in the bottom of the tower
first_turtle.forward(80) 
first_turtle.left(135)
first_turtle.forward(120)

# Create the shape triangle as the second turtle and get it to design the interior part of the tower
second_turtle = turtle.Turtle() # Create an instance of the second turtle
second_turtle .shape("classic") # Also, in this library there are other shapes possible, such as circle, square, arrow, turtle, triangle, classic) 
second_turtle .color("cyan2") # Set a colour of red
second_turtle.width(1) # set a pen size 

# Change the speed of the Turtle's movement
first_turtle.speed(0)
second_turtle.speed(0)

# Performing the first line of the right part in the bottom-inside of the tower
second_turtle .forward(80)
second_turtle .left(180)
second_turtle .forward(5)

# Preparing the whole inside disign by means of a "for range" with one variable of x changing from 0 to 1.5
# This part is the right column's decoration
x = 0
for i in range(4):
    second_turtle .right(45 + x*2)
    second_turtle .forward(120)
    for i in range(45):
        second_turtle.right(1 + x*0.8)
        second_turtle.forward(1)
    second_turtle .left(90)
    second_turtle .forward(3)
    second_turtle .left(90)
    for i in range(45):
        second_turtle .left(1 + x*0.8)
        second_turtle .forward(1)
    second_turtle.forward(120 + x*2.7)
    second_turtle.right(135)
    if x < 1.5:
        second_turtle.forward(5 + x*14)
    x = x + 0.5

# second_turtle.right(180)
# second_turtle.forward(26)
second_turtle.left(6.4)
second_turtle.forward(196.5)
second_turtle.right(180)
    
# Shape a curved line at the right side of our tower
for i in range(45):
    first_turtle.right(1)
    first_turtle.forward(1)
    
# Go up to the top of the tower    
first_turtle.forward(32)

# Making the top part of the tower
first_turtle.left(90)
first_turtle.forward(38)

# Providing the left side of the top part
first_turtle.left(90)
first_turtle.forward(32)

# Establishing the left curved line by using a loop
for i in range(45):
    first_turtle.right(1)
    first_turtle.forward(1)

# Presenting the left bottom part of it
first_turtle.forward(120)
first_turtle.left(135)
first_turtle.forward(82)

# Building the left short column
first_turtle.left(80)
first_turtle.forward(50)

# Taking benefit of a simple loop for producing a semicircle as the arch of the tower
for i in range(84):
    first_turtle.right(2.05)
    first_turtle.forward(1.08)

# Constructing the right column under the arch
first_turtle.left(10)
first_turtle.forward(42)
first_turtle.left(80)
first_turtle.forward(10)

# Preparing the whole inside disign by means of a "for range" with one variable of x changing from 0 to 1.5
# This part is the left column's decoration
x = 0
for i in range(4):
    second_turtle.left(45 + x*2)
    second_turtle.forward(120)
    for i in range(45):
        second_turtle.left(1 + x*0.8)
        second_turtle.forward(1)
    second_turtle.right(90)
    second_turtle.forward(3)
    second_turtle.right(90)
    for i in range(45):
        second_turtle.right(1 + x*0.8)
        second_turtle .forward(1)
    second_turtle.forward(120 + x*2.7)
    second_turtle.left(135)
    if x < 1.5:
        second_turtle.forward(5 + x*14)
    x = x + 0.5

# Transferring both turtles to the new position and then setting them horizontal
first_turtle.color("white")
first_turtle.setpos(-41,-123)
second_turtle.color("white")
second_turtle.setpos(-41,-123)
first_turtle.left(3)
second_turtle.right(6)

# Defining the colors in variables
y0 = "orange"
y1 = "red"
y2 = "green"
y3 = "yellow"
y4 = "blue"
y5 = "black"
y6 = "white"
y7 = "violet"
x = 0
color_code = y0

# Drawing two circles of green ground areas with small water streams and white marblae boundries by operating the "while" loop and "if function". 
while x != 721: 
    if x <= 360:
        move = -1.1
    else:
        move = 1.1
    first_turtle.color(color_code)
    first_turtle.width(3)
    first_turtle.forward(move)
    first_turtle.right(1)
    if x % 12 == 0: 
        for xx in range (360):
            if (xx < 30 or xx < 210 and xx > 150 or xx > 330 and xx <= 360):
                second_turtle.color(y4)
            elif (xx < 40 or xx > 140 and xx < 150 or xx > 210 and xx < 220 or xx > 330 and xx < 360):
                second_turtle.color(y6)
            elif (xx < 140 or xx > 220 and xx < 320):
                second_turtle.color(y2)
            second_turtle.forward(x/360-1)
            second_turtle.right(1)
    x += 1
    i = x % 7 
    if i == 0:
        color_code = y0
    elif i == 1:
        color_code = y1
    elif i == 2:
        color_code = y2
    elif i == 3:
        color_code = y3
    elif i == 4:
        color_code = y4
    elif i == 5:
        color_code = y5
    elif i == 6:
        color_code = y6
    else:
        color_code = y7
print("The End")
# Out:
# The End
